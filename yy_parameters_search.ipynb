# %%
import pandas as pd

# %%
df = pd.read_csv(
    "https://www.openml.org/data/get_csv/16826755/phpMYEkMl.csv",
    na_values='?'
)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
X_df = df.drop(columns='survived')
y = df['survived']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_df, y, random_state=42
)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier

num_cols = ['age', 'parch', 'fare']
cat_col = ['sex', 'embarked', 'pclass']
preprocessing = make_column_transformer(
    (make_pipeline(SimpleImputer(strategy='constant', fill_value='missing'),
                   OrdinalEncoder()),
     cat_col),
    (SimpleImputer(strategy='mean'), num_cols)
)

model = make_pipeline(preprocessing, RandomForestClassifier())
model.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.7804878048780488

# %%
model.set_params(randomforesclassifier)
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                      transformer_weights=None,
#                      transformers=[('pipeline',
#                                     Pipeline(memory=None,
#                                              steps=[('simpleimputer',
#                                                      SimpleImputer(add_indicator=False,
#                                                                    copy=True,
#                                                                    fill_value='missing',
#                                                                    missing_values=nan,
#                                                                    strategy='constant',
#                                                                    verbose=0)),
#                                                     ('ordinalencoder',
#                                                      OrdinalEncoder(categories='auto',
#                                                                     dtype=<class 'numpy.float64'>))],
#                                              verbose=False),
#                                     ['sex', 'embarked', 'pclass']),
#                                    ('simpleimputer',
#                                     SimpleImputer(add_indicator=False, copy=True,
#                                                   fill_value=None,
#                                                   missing_values=nan,
#                                                   strategy='mean', verbose=0),
#                                     ['age', 'parch', 'fare'])],
#                      verbose=False)),
#   ('randomforestclassifier',
#    RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False))],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                    transformer_weights=None,
#                    transformers=[('pipeline',
#                                   Pipeline(memory=None,
#                                            steps=[('simpleimputer',
#                                                    SimpleImputer(add_indicator=False,
#                                                                  copy=True,
#                                                                  fill_value='missing',
#                                                                  missing_values=nan,
#                                                                  strategy='constant',
#                                                                  verbose=0)),
#                                                   ('ordinalencoder',
#                                                    OrdinalEncoder(categories='auto',
#                                                                   dtype=<class 'numpy.float64'>))],
#                                            verbose=False),
#                                   ['sex', 'embarked', 'pclass']),
#                                  ('simpleimputer',
#                                   SimpleImputer(add_indicator=False, copy=True,
#                                                 fill_value=None,
#                                                 missing_values=nan,
#                                                 strategy='mean', verbose=0),
#                                   ['age', 'parch', 'fare'])],
#                    verbose=False),
#  'randomforestclassifier': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=None, max_features='auto',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('pipeline', Pipeline(memory=None,
#             steps=[('simpleimputer',
#                     SimpleImputer(add_indicator=False, copy=True,
#                                   fill_value='missing', missing_values=nan,
#                                   strategy='constant', verbose=0)),
#                    ('ordinalencoder',
#                     OrdinalEncoder(categories='auto',
#                                    dtype=<class 'numpy.float64'>))],
#             verbose=False), ['sex', 'embarked', 'pclass']),
#   ('simpleimputer',
#    SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                  missing_values=nan, strategy='mean', verbose=0),
#    ['age', 'parch', 'fare'])],
#  'columntransformer__verbose': False,
#  'columntransformer__pipeline': Pipeline(memory=None,
#           steps=[('simpleimputer',
#                   SimpleImputer(add_indicator=False, copy=True,
#                                 fill_value='missing', missing_values=nan,
#                                 strategy='constant', verbose=0)),
#                  ('ordinalencoder',
#                   OrdinalEncoder(categories='auto',
#                                  dtype=<class 'numpy.float64'>))],
#           verbose=False),
#  'columntransformer__simpleimputer': SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                missing_values=nan, strategy='mean', verbose=0),
#  'columntransformer__pipeline__memory': None,
#  'columntransformer__pipeline__steps': [('simpleimputer',
#    SimpleImputer(add_indicator=False, copy=True, fill_value='missing',
#                  missing_values=nan, strategy='constant', verbose=0)),
#   ('ordinalencoder',
#    OrdinalEncoder(categories='auto', dtype=<class 'numpy.float64'>))],
#  'columntransformer__pipeline__verbose': False,
#  'columntransformer__pipeline__simpleimputer': SimpleImputer(add_indicator=False, copy=True, fill_value='missing',
#                missing_values=nan, strategy='constant', verbose=0),
#  'columntransformer__pipeline__ordinalencoder': OrdinalEncoder(categories='auto', dtype=<class 'numpy.float64'>),
#  'columntransformer__pipeline__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline__simpleimputer__copy': True,
#  'columntransformer__pipeline__simpleimputer__fill_value': 'missing',
#  'columntransformer__pipeline__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline__simpleimputer__strategy': 'constant',
#  'columntransformer__pipeline__simpleimputer__verbose': 0,
#  'columntransformer__pipeline__ordinalencoder__categories': 'auto',
#  'columntransformer__pipeline__ordinalencoder__dtype': numpy.float64,
#  'columntransformer__simpleimputer__add_indicator': False,
#  'columntransformer__simpleimputer__copy': True,
#  'columntransformer__simpleimputer__fill_value': None,
#  'columntransformer__simpleimputer__missing_values': nan,
#  'columntransformer__simpleimputer__strategy': 'mean',
#  'columntransformer__simpleimputer__verbose': 0,
#  'randomforestclassifier__bootstrap': True,
#  'randomforestclassifier__ccp_alpha': 0.0,
#  'randomforestclassifier__class_weight': None,
#  'randomforestclassifier__criterion': 'gini',
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__max_features': 'auto',
#  'randomforestclassifier__max_leaf_nodes': None,
#  'randomforestclassifier__max_samples': None,
#  'randomforestclassifier__min_impurity_decrease': 0.0,
#  'randomforestclassifier__min_impurity_split': None,
#  'randomforestclassifier__min_samples_leaf': 1,
#  'randomforestclassifier__min_samples_split': 2,
#  'randomforestclassifier__min_weight_fraction_leaf': 0.0,
#  'randomforestclassifier__n_estimators': 100,
#  'randomforestclassifier__n_jobs': None,
#  'randomforestclassifier__oob_score': False,
#  'randomforestclassifier__random_state': None,
#  'randomforestclassifier__verbose': 0,
#  'randomforestclassifier__warm_start': False}

# %%
preprocessing = make_column_transformer(
    (make_pipeline(SimpleImputer(strategy='constant', fill_value='missing'),
                   OrdinalEncoder()),
     cat_col),
    (SimpleImputer(strategy='mean'), num_cols)
)

model = make_pipeline(preprocessing, RandomForestClassifier())
model.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('pipeline',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value='missing',
#                                                                                  missing_values=nan,
#                                                                                  strategy='constant',
#                                                                                  verbose=0)),
#                                                                   ('ordinalencoder',
#                                                                    Ord...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.7957317073170732
